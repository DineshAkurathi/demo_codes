# %%
# %cd ..
# Out:
# C:\Users

# %%
# %cd akura/individual_project_v1/
# Out:
# C:\Users\akura\individual_project_v1

# %%
# set up our code
# %pip install -r requirements.txt
# %pip install -e .

# install gradio
# %pip install --upgrade gradio

# set up Grounded-SAM
# you will need to clone Grounded-SAM repo
# !git clone https://github.com/IDEA-Research/Grounded-Segment-Anything.git
# %cd ./Grounded-Segment-Anything
# %pip install -r ./requirements.txt
# %pip install ./segment_anything
# %pip install ./GroundingDINO
# %cd ..
# %pip install opencv-python pycocotools matplotlib onnxruntime onnx ipykernel
# Out:
# Collecting clip@ git+https://github.com/openai/CLIP.git (from -r requirements.txt (line 9))
#   Cloning https://github.com/openai/CLIP.git to c:\users\akura\appdata\local\temp\pip-install-y3sgb6q6\clip_eaff922fc0254ce9809234e017cc70a5
#   Resolved https://github.com/openai/CLIP.git to commit a1d071733d7111c9c014f024669f959182114e33
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: timm==0.4.12 in c:\users\akura\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from -r requirements.txt (line 1)) (0.4.12)
# Requirement already satisfied: transformers==4.25.1 in c:\users\akura\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from -r requirements.txt (line 2)) (4.25.1)
# Requirement already satisfied: fairscale==0.4.4 in c:\users\akura\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from -r requirements.txt (line 3)) (0.4.4)
# Requirement already satisfied: pycocoevalcap in c:\users\akura\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from -r requirements.txt (line 4)) (1.2)
# Requirement already satisfied: torch in c:\users\akura\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from -r requirements.txt (line 5)) (2.1.0)
# Requirement already satisfied: torchvision in c:\users\akura\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from -r requirements.txt (line 6)) (0.16.0)
# Requirement already satisfied: Pillow in c:\users\akura\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from -r requirements.txt (line 7)) (10.1.0)
# Requirement already satisfied: scipy in c:\users\akura\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from -r requirements.txt (line 8)) (1.11.3)
# Requirement already satisfied: filelock in c:\users\akura\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from transformers==4.25.1->-r requirements.txt (line 2)) (3.12.4)
# Requirement already satisfied: huggingface-hub<1.0,>=0.10.0 in c:\users\akura\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from transformers==4.25.1->-r requirements.txt (line 2)) (0.18.0)
# Requirement already satisfied: numpy>=1.17 in c:\users\akura\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from transformers==4.25.1->-r requirements.txt (line 2)) (1.26.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\akura\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from transformers==4.25.1->-r requirements.txt (line 2)) (22.0)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\akura\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from transformers==4.25.1->-r requirements.txt (line 2)) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\akura\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from transformers==4.25.1->-r requirements.txt (line 2)) (2023.10.3)
# Requirement already satisfied: requests in c:\users\akura\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from transformers==4.25.1->-r requirements.txt (line 2)) (2.31.0)
# Requirement already satisfied: tokenizers!=0.11.3,<0.14,>=0.11.1 in c:\users\akura\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from transformers==4.25.1->-r requirements.txt (line 2)) (0.13.3)
# Requirement already satisfied: tqdm>=4.27 in c:\users\akura\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from transformers==4.25.1->-r requirements.txt (line 2)) (4.66.1)
# Requirement already satisfied: pycocotools>=2.0.2 in c:\users\akura\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from pycocoevalcap->-r requirements.txt (line 4)) (2.0.7)
# Requirement already satisfied: typing-extensions in c:\users\akura\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from torch->-r requirements.txt (line 5)) (4.8.0)
# Requirement already satisfied: sympy in c:\users\akura\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from torch->-r requirements.txt (line 5)) (1.12)
# Requirement already satisfied: networkx in c:\users\akura\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from torch->-r requirements.txt (line 5)) (3.1)
# Requirement already satisfied: jinja2 in c:\users\akura\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from torch->-r requirements.txt (line 5)) (3.1.2)
# Requirement already satisfied: fsspec in c:\users\akura\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from torch->-r requirements.txt (line 5)) (2023.9.2)
# Requirement already satisfied: ftfy in c:\users\akura\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from clip@ git+https://github.com/openai/CLIP.git->-r requirements.txt (line 9)) (6.1.1)
# Requirement already satisfied: matplotlib>=2.1.0 in c:\users\akura\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from pycocotools>=2.0.2->pycocoevalcap->-r requirements.txt (line 4)) (3.8.0)
# Requirement already satisfied: colorama in c:\users\akura\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from tqdm>=4.27->transformers==4.25.1->-r requirements.txt (line 2)) (0.4.6)
# Requirement already satisfied: wcwidth>=0.2.5 in c:\users\akura\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from ftfy->clip@ git+https://github.com/openai/CLIP.git->-r requirements.txt (line 9)) (0.2.5)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\akura\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from jinja2->torch->-r requirements.txt (line 5)) (2.1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\akura\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from requests->transformers==4.25.1->-r requirements.txt (line 2)) (3.3.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\akura\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from requests->transformers==4.25.1->-r requirements.txt (line 2)) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\akura\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from requests->transformers==4.25.1->-r requirements.txt (line 2)) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\akura\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from requests->transformers==4.25.1->-r requirements.txt (line 2)) (2023.7.22)
# Requirement already satisfied: mpmath>=0.19 in c:\users\akura\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from sympy->torch->-r requirements.txt (line 5)) (1.3.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\akura\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from matplotlib>=2.1.0->pycocotools>=2.0.2->pycocoevalcap->-r requirements.txt (line 4)) (1.1.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\akura\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from matplotlib>=2.1.0->pycocotools>=2.0.2->pycocoevalcap->-r requirements.txt (line 4)) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\akura\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from matplotlib>=2.1.0->pycocotools>=2.0.2->pycocoevalcap->-r requirements.txt (line 4)) (4.43.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\akura\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from matplotlib>=2.1.0->pycocotools>=2.0.2->pycocoevalcap->-r requirements.txt (line 4)) (1.4.5)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\akura\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from matplotlib>=2.1.0->pycocotools>=2.0.2->pycocoevalcap->-r requirements.txt (line 4)) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\akura\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from matplotlib>=2.1.0->pycocotools>=2.0.2->pycocoevalcap->-r requirements.txt (line 4)) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\akura\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from python-dateutil>=2.7->matplotlib>=2.1.0->pycocotools>=2.0.2->pycocoevalcap->-r requirements.txt (line 4)) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.
#   Running command git clone --filter=blob:none --quiet https://github.com/openai/CLIP.git 'C:\Users\akura\AppData\Local\Temp\pip-install-y3sgb6q6\clip_eaff922fc0254ce9809234e017cc70a5'
#
# [notice] A new release of pip is available: 23.2.1 -> 23.3
# [notice] To update, run: C:\Users\akura\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip
# Obtaining file:///C:/Users/akura/individual_project_v1
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting clip@ git+https://github.com/openai/CLIP.git (from ram==0.0.1)
#   Cloning https://github.com/openai/CLIP.git to c:\users\akura\appdata\local\temp\pip-install-btd9_5y8\clip_2ac61441bf3548ca8f2d19f845b239d9
#   Resolved https://github.com/openai/CLIP.git to commit a1d071733d7111c9c014f024669f959182114e33
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: timm==0.4.12 in c:\users\akura\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from ram==0.0.1) (0.4.12)
# Requirement already satisfied: transformers==4.25.1 in c:\users\akura\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from ram==0.0.1) (4.25.1)
# Requirement already satisfied: fairscale==0.4.4 in c:\users\akura\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from ram==0.0.1) (0.4.4)
# Requirement already satisfied: pycocoevalcap in c:\users\akura\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from ram==0.0.1) (1.2)
# Requirement already satisfied: torch in c:\users\akura\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from ram==0.0.1) (2.1.0)
# Requirement already satisfied: torchvision in c:\users\akura\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from ram==0.0.1) (0.16.0)
# Requirement already satisfied: Pillow in c:\users\akura\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from ram==0.0.1) (10.1.0)
# Requirement already satisfied: scipy in c:\users\akura\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from ram==0.0.1) (1.11.3)
# Requirement already satisfied: filelock in c:\users\akura\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from transformers==4.25.1->ram==0.0.1) (3.12.4)
# Requirement already satisfied: huggingface-hub<1.0,>=0.10.0 in c:\users\akura\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from transformers==4.25.1->ram==0.0.1) (0.18.0)
# Requirement already satisfied: numpy>=1.17 in c:\users\akura\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from transformers==4.25.1->ram==0.0.1) (1.26.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\akura\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from transformers==4.25.1->ram==0.0.1) (22.0)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\akura\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from transformers==4.25.1->ram==0.0.1) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\akura\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from transformers==4.25.1->ram==0.0.1) (2023.10.3)
# Requirement already satisfied: requests in c:\users\akura\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from transformers==4.25.1->ram==0.0.1) (2.31.0)
# Requirement already satisfied: tokenizers!=0.11.3,<0.14,>=0.11.1 in c:\users\akura\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from transformers==4.25.1->ram==0.0.1) (0.13.3)
# Requirement already satisfied: tqdm>=4.27 in c:\users\akura\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from transformers==4.25.1->ram==0.0.1) (4.66.1)
# Requirement already satisfied: typing-extensions in c:\users\akura\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from torch->ram==0.0.1) (4.8.0)
# Requirement already satisfied: sympy in c:\users\akura\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from torch->ram==0.0.1) (1.12)
# Requirement already satisfied: networkx in c:\users\akura\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from torch->ram==0.0.1) (3.1)
# Requirement already satisfied: jinja2 in c:\users\akura\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from torch->ram==0.0.1) (3.1.2)
# Requirement already satisfied: fsspec in c:\users\akura\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from torch->ram==0.0.1) (2023.9.2)
# Requirement already satisfied: ftfy in c:\users\akura\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from clip@ git+https://github.com/openai/CLIP.git->ram==0.0.1) (6.1.1)
# Requirement already satisfied: pycocotools>=2.0.2 in c:\users\akura\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from pycocoevalcap->ram==0.0.1) (2.0.7)
# Requirement already satisfied: matplotlib>=2.1.0 in c:\users\akura\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from pycocotools>=2.0.2->pycocoevalcap->ram==0.0.1) (3.8.0)
# Requirement already satisfied: colorama in c:\users\akura\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from tqdm>=4.27->transformers==4.25.1->ram==0.0.1) (0.4.6)
# Requirement already satisfied: wcwidth>=0.2.5 in c:\users\akura\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from ftfy->clip@ git+https://github.com/openai/CLIP.git->ram==0.0.1) (0.2.5)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\akura\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from jinja2->torch->ram==0.0.1) (2.1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\akura\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from requests->transformers==4.25.1->ram==0.0.1) (3.3.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\akura\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from requests->transformers==4.25.1->ram==0.0.1) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\akura\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from requests->transformers==4.25.1->ram==0.0.1) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\akura\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from requests->transformers==4.25.1->ram==0.0.1) (2023.7.22)
# Requirement already satisfied: mpmath>=0.19 in c:\users\akura\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from sympy->torch->ram==0.0.1) (1.3.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\akura\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from matplotlib>=2.1.0->pycocotools>=2.0.2->pycocoevalcap->ram==0.0.1) (1.1.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\akura\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from matplotlib>=2.1.0->pycocotools>=2.0.2->pycocoevalcap->ram==0.0.1) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\akura\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from matplotlib>=2.1.0->pycocotools>=2.0.2->pycocoevalcap->ram==0.0.1) (4.43.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\akura\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from matplotlib>=2.1.0->pycocotools>=2.0.2->pycocoevalcap->ram==0.0.1) (1.4.5)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\akura\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from matplotlib>=2.1.0->pycocotools>=2.0.2->pycocoevalcap->ram==0.0.1) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\akura\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from matplotlib>=2.1.0->pycocotools>=2.0.2->pycocoevalcap->ram==0.0.1) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\akura\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from python-dateutil>=2.7->matplotlib>=2.1.0->pycocotools>=2.0.2->pycocoevalcap->ram==0.0.1) (1.16.0)
# Installing collected packages: ram
#   Attempting uninstall: ram
#     Found existing installation: ram 0.0.1
#     Uninstalling ram-0.0.1:
#       Successfully uninstalled ram-0.0.1
#   Running setup.py develop for ram
# Successfully installed ram-0.0.1
# Note: you may need to restart the kernel to use updated packages.
#   Running command git clone --filter=blob:none --quiet https://github.com/openai/CLIP.git 'C:\Users\akura\AppData\Local\Temp\pip-install-btd9_5y8\clip_2ac61441bf3548ca8f2d19f845b239d9'
#
# [notice] A new release of pip is available: 23.2.1 -> 23.3
# [notice] To update, run: C:\Users\akura\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip
# Requirement already satisfied: gradio in c:\users\akura\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (3.48.0)Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.2.1 -> 23.3
# [notice] To update, run: C:\Users\akura\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip
# Requirement already satisfied: aiofiles<24.0,>=22.0 in c:\users\akura\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from gradio) (23.2.1)
# Requirement already satisfied: altair<6.0,>=4.2.0 in c:\users\akura\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from gradio) (5.1.2)
# Requirement already satisfied: fastapi in c:\users\akura\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from gradio) (0.103.2)
# Requirement already satisfied: ffmpy in c:\users\akura\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from gradio) (0.3.1)
# Requirement already satisfied: gradio-client==0.6.1 in c:\users\akura\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from gradio) (0.6.1)
# Requirement already satisfied: httpx in c:\users\akura\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from gradio) (0.25.0)
# Requirement already satisfied: huggingface-hub>=0.14.0 in c:\users\akura\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from gradio) (0.18.0)
# Requirement already satisfied: importlib-resources<7.0,>=1.3 in c:\users\akura\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from gradio) (6.1.0)
# Requirement already satisfied: jinja2<4.0 in c:\users\akura\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from gradio) (3.1.2)
# Requirement already satisfied: markupsafe~=2.0 in c:\users\akura\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from gradio) (2.1.3)
# Requirement already satisfied: matplotlib~=3.0 in c:\users\akura\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from gradio) (3.8.0)
# Requirement already satisfied: numpy~=1.0 in c:\users\akura\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from gradio) (1.26.0)
# Requirement already satisfied: orjson~=3.0 in c:\users\akura\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from gradio) (3.9.9)
# Requirement already satisfied: packaging in c:\users\akura\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from gradio) (22.0)
# Requirement already satisfied: pandas<3.0,>=1.0 in c:\users\akura\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from gradio) (2.1.1)
# Requirement already satisfied: pillow<11.0,>=8.0 in c:\users\akura\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from gradio) (10.1.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,!=2.0.0,!=2.0.1,<3.0.0,>=1.7.4 in c:\users\akura\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from gradio) (2.4.2)
# Requirement already satisfied: pydub in c:\users\akura\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from gradio) (0.25.1)
# Requirement already satisfied: python-multipart in c:\users\akura\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from gradio) (0.0.6)
# Requirement already satisfied: pyyaml<7.0,>=5.0 in c:\users\akura\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from gradio) (6.0.1)
# Requirement already satisfied: requests~=2.0 in c:\users\akura\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from gradio) (2.31.0)
# Requirement already satisfied: semantic-version~=2.0 in c:\users\akura\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from gradio) (2.10.0)
# Requirement already satisfied: typing-extensions~=4.0 in c:\users\akura\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from gradio) (4.8.0)
# Requirement already satisfied: uvicorn>=0.14.0 in c:\users\akura\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from gradio) (0.23.2)
# Requirement already satisfied: websockets<12.0,>=10.0 in c:\users\akura\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from gradio) (11.0.3)
# Requirement already satisfied: fsspec in c:\users\akura\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from gradio-client==0.6.1->gradio) (2023.9.2)
# Requirement already satisfied: jsonschema>=3.0 in c:\users\akura\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from altair<6.0,>=4.2.0->gradio) (4.19.1)
# Requirement already satisfied: toolz in c:\users\akura\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from altair<6.0,>=4.2.0->gradio) (0.12.0)
# Requirement already satisfied: filelock in c:\users\akura\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from huggingface-hub>=0.14.0->gradio) (3.12.4)
# Requirement already satisfied: tqdm>=4.42.1 in c:\users\akura\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from huggingface-hub>=0.14.0->gradio) (4.66.1)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\akura\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from matplotlib~=3.0->gradio) (1.1.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\akura\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from matplotlib~=3.0->gradio) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\akura\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from matplotlib~=3.0->gradio) (4.43.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\akura\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from matplotlib~=3.0->gradio) (1.4.5)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\akura\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from matplotlib~=3.0->gradio) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\akura\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from matplotlib~=3.0->gradio) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\akura\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from pandas<3.0,>=1.0->gradio) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\akura\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from pandas<3.0,>=1.0->gradio) (2023.3)
# Requirement already satisfied: annotated-types>=0.4.0 in c:\users\akura\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from pydantic!=1.8,!=1.8.1,!=2.0.0,!=2.0.1,<3.0.0,>=1.7.4->gradio) (0.6.0)
# Requirement already satisfied: pydantic-core==2.10.1 in c:\users\akura\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from pydantic!=1.8,!=1.8.1,!=2.0.0,!=2.0.1,<3.0.0,>=1.7.4->gradio) (2.10.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\akura\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from requests~=2.0->gradio) (3.3.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\akura\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from requests~=2.0->gradio) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\akura\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from requests~=2.0->gradio) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\akura\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from requests~=2.0->gradio) (2023.7.22)
# Requirement already satisfied: click>=7.0 in c:\users\akura\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from uvicorn>=0.14.0->gradio) (8.1.7)
# Requirement already satisfied: h11>=0.8 in c:\users\akura\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from uvicorn>=0.14.0->gradio) (0.14.0)
# Requirement already satisfied: anyio<4.0.0,>=3.7.1 in c:\users\akura\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from fastapi->gradio) (3.7.1)
# Requirement already satisfied: starlette<0.28.0,>=0.27.0 in c:\users\akura\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from fastapi->gradio) (0.27.0)
# Requirement already satisfied: httpcore<0.19.0,>=0.18.0 in c:\users\akura\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from httpx->gradio) (0.18.0)
# Requirement already satisfied: sniffio in c:\users\akura\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from httpx->gradio) (1.3.0)
# Requirement already satisfied: exceptiongroup in c:\users\akura\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from anyio<4.0.0,>=3.7.1->fastapi->gradio) (1.1.3)
# Requirement already satisfied: colorama in c:\users\akura\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from click>=7.0->uvicorn>=0.14.0->gradio) (0.4.6)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\akura\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from jsonschema>=3.0->altair<6.0,>=4.2.0->gradio) (23.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\akura\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from jsonschema>=3.0->altair<6.0,>=4.2.0->gradio) (2023.7.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\akura\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from jsonschema>=3.0->altair<6.0,>=4.2.0->gradio) (0.30.2)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\akura\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from jsonschema>=3.0->altair<6.0,>=4.2.0->gradio) (0.10.6)
# Requirement already satisfied: six>=1.5 in c:\users\akura\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from python-dateutil>=2.7->matplotlib~=3.0->gradio) (1.16.0)
# C:\Users\akura\individual_project_v1\Grounded-Segment-Anything
# Cloning into 'Grounded-Segment-Anything'...
# Updating files:  51% (117/226)
# Updating files:  52% (118/226)
# Updating files:  53% (120/226)
# Updating files:  54% (123/226)
# Updating files:  55% (125/226)
# Updating files:  56% (127/226)
# Updating files:  57% (129/226)
# Updating files:  58% (132/226)
# Updating files:  59% (134/226)
# Updating files:  60% (136/226)
# Updating files:  61% (138/226)
# Updating files:  62% (141/226)
# Updating files:  63% (143/226)
# Updating files:  64% (145/226)
# Updating files:  65% (147/226)
# Updating files:  66% (150/226)
# Updating files:  67% (152/226)
# Updating files:  68% (154/226)
# Updating files:  69% (156/226)
# Updating files:  70% (159/226)
# Updating files:  71% (161/226)
# Updating files:  72% (163/226)
# Updating files:  73% (165/226)
# Updating files:  74% (168/226)
# Updating files:  75% (170/226)
# Updating files:  76% (172/226)
# Updating files:  77% (175/226)
# Updating files:  78% (177/226)
# Updating files:  79% (179/226)
# Updating files:  80% (181/226)
# Updating files:  81% (184/226)
# Updating files:  82% (186/226)
# Updating files:  83% (188/226)
# Updating files:  84% (190/226)
# Updating files:  85% (193/226)
# Updating files:  86% (195/226)
# Updating files:  87% (197/226)
# Updating files:  88% (199/226)
# Updating files:  89% (202/226)
# Updating files:  90% (204/226)
# Updating files:  91% (206/226)
# Updating files:  92% (208/226)
# Updating files:  93% (211/226)
# Updating files:  94% (213/226)
# Updating files:  94% (214/226)
# Updating files:  95% (215/226)
# Updating files:  96% (217/226)
# Updating files:  97% (220/226)
# Updating files:  98% (222/226)
# Updating files:  99% (224/226)
# Updating files: 100% (226/226)
# Updating files: 100% (226/226), done.
# Requirement already satisfied: addict in c:\users\akura\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from -r ./requirements.txt (line 1)) (2.4.0)Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.2.1 -> 23.3
# [notice] To update, run: C:\Users\akura\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip
# Requirement already satisfied: diffusers in c:\users\akura\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from -r ./requirements.txt (line 2)) (0.21.4)
# Requirement already satisfied: gradio in c:\users\akura\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from -r ./requirements.txt (line 3)) (3.48.0)
# Requirement already satisfied: huggingface_hub in c:\users\akura\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from -r ./requirements.txt (line 4)) (0.18.0)
# Requirement already satisfied: matplotlib in c:\users\akura\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from -r ./requirements.txt (line 5)) (3.8.0)
# Requirement already satisfied: numpy in c:\users\akura\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from -r ./requirements.txt (line 6)) (1.26.0)
# Requirement already satisfied: onnxruntime in c:\users\akura\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from -r ./requirements.txt (line 7)) (1.16.1)
# Requirement already satisfied: opencv_python in c:\users\akura\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from -r ./requirements.txt (line 8)) (4.8.1.78)
# Requirement already satisfied: Pillow in c:\users\akura\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from -r ./requirements.txt (line 9)) (10.1.0)
# Requirement already satisfied: pycocotools in c:\users\akura\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from -r ./requirements.txt (line 10)) (2.0.7)
# Requirement already satisfied: PyYAML in c:\users\akura\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from -r ./requirements.txt (line 11)) (6.0.1)
# Requirement already satisfied: requests in c:\users\akura\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from -r ./requirements.txt (line 12)) (2.31.0)
# Requirement already satisfied: setuptools in c:\program files\windowsapps\pythonsoftwarefoundation.python.3.10_3.10.3056.0_x64__qbz5n2kfra8p0\lib\site-packages (from -r ./requirements.txt (line 13)) (65.5.0)
# Requirement already satisfied: supervision in c:\users\akura\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from -r ./requirements.txt (line 14)) (0.15.0)
# Requirement already satisfied: termcolor in c:\users\akura\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from -r ./requirements.txt (line 15)) (2.3.0)
# Requirement already satisfied: timm in c:\users\akura\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from -r ./requirements.txt (line 16)) (0.4.12)
# Requirement already satisfied: torch in c:\users\akura\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from -r ./requirements.txt (line 17)) (2.1.0)
# Requirement already satisfied: torchvision in c:\users\akura\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from -r ./requirements.txt (line 18)) (0.16.0)
# Requirement already satisfied: transformers in c:\users\akura\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from -r ./requirements.txt (line 19)) (4.25.1)
# Requirement already satisfied: yapf in c:\users\akura\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from -r ./requirements.txt (line 20)) (0.40.2)
# Requirement already satisfied: nltk in c:\users\akura\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from -r ./requirements.txt (line 21)) (3.8.1)
# Requirement already satisfied: fairscale in c:\users\akura\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from -r ./requirements.txt (line 22)) (0.4.4)
# Requirement already satisfied: litellm in c:\users\akura\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from -r ./requirements.txt (line 23)) (0.9.2)
# Requirement already satisfied: filelock in c:\users\akura\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from diffusers->-r ./requirements.txt (line 2)) (3.12.4)
# Requirement already satisfied: importlib-metadata in c:\users\akura\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from diffusers->-r ./requirements.txt (line 2)) (6.8.0)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\akura\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from diffusers->-r ./requirements.txt (line 2)) (2023.10.3)
# Requirement already satisfied: safetensors>=0.3.1 in c:\users\akura\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from diffusers->-r ./requirements.txt (line 2)) (0.4.0)
# Requirement already satisfied: aiofiles<24.0,>=22.0 in c:\users\akura\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from gradio->-r ./requirements.txt (line 3)) (23.2.1)
# Requirement already satisfied: altair<6.0,>=4.2.0 in c:\users\akura\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from gradio->-r ./requirements.txt (line 3)) (5.1.2)
# Requirement already satisfied: fastapi in c:\users\akura\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from gradio->-r ./requirements.txt (line 3)) (0.103.2)
# Requirement already satisfied: ffmpy in c:\users\akura\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from gradio->-r ./requirements.txt (line 3)) (0.3.1)
# Requirement already satisfied: gradio-client==0.6.1 in c:\users\akura\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from gradio->-r ./requirements.txt (line 3)) (0.6.1)
# Requirement already satisfied: httpx in c:\users\akura\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from gradio->-r ./requirements.txt (line 3)) (0.25.0)
# Requirement already satisfied: importlib-resources<7.0,>=1.3 in c:\users\akura\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from gradio->-r ./requirements.txt (line 3)) (6.1.0)
# Requirement already satisfied: jinja2<4.0 in c:\users\akura\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from gradio->-r ./requirements.txt (line 3)) (3.1.2)
# Requirement already satisfied: markupsafe~=2.0 in c:\users\akura\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from gradio->-r ./requirements.txt (line 3)) (2.1.3)
# Requirement already satisfied: orjson~=3.0 in c:\users\akura\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from gradio->-r ./requirements.txt (line 3)) (3.9.9)
# Requirement already satisfied: packaging in c:\users\akura\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from gradio->-r ./requirements.txt (line 3)) (22.0)
# Requirement already satisfied: pandas<3.0,>=1.0 in c:\users\akura\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from gradio->-r ./requirements.txt (line 3)) (2.1.1)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,!=2.0.0,!=2.0.1,<3.0.0,>=1.7.4 in c:\users\akura\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from gradio->-r ./requirements.txt (line 3)) (2.4.2)
# Requirement already satisfied: pydub in c:\users\akura\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from gradio->-r ./requirements.txt (line 3)) (0.25.1)
# Requirement already satisfied: python-multipart in c:\users\akura\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from gradio->-r ./requirements.txt (line 3)) (0.0.6)
# Requirement already satisfied: semantic-version~=2.0 in c:\users\akura\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from gradio->-r ./requirements.txt (line 3)) (2.10.0)
# Requirement already satisfied: typing-extensions~=4.0 in c:\users\akura\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from gradio->-r ./requirements.txt (line 3)) (4.8.0)
# Requirement already satisfied: uvicorn>=0.14.0 in c:\users\akura\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from gradio->-r ./requirements.txt (line 3)) (0.23.2)
# ...
# Requirement already satisfied: cycler>=0.10 in c:\users\akura\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from matplotlib>=2.1.0->pycocotools->groundingdino==0.1.0) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\akura\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from matplotlib>=2.1.0->pycocotools->groundingdino==0.1.0) (4.43.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\akura\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from matplotlib>=2.1.0->pycocotools->groundingdino==0.1.0) (1.4.5)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\akura\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from matplotlib>=2.1.0->pycocotools->groundingdino==0.1.0) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\akura\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from matplotlib>=2.1.0->pycocotools->groundingdino==0.1.0) (2.8.2)
# Requirement already satisfied: colorama in c:\users\akura\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from tqdm>=4.27->transformers->groundingdino==0.1.0) (0.4.6)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\akura\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from jinja2->torch->groundingdino==0.1.0) (2.1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\akura\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from requests->torchvision->groundingdino==0.1.0) (3.3.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\akura\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from requests->torchvision->groundingdino==0.1.0) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\akura\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from requests->torchvision->groundingdino==0.1.0) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\akura\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from requests->torchvision->groundingdino==0.1.0) (2023.7.22)
# Requirement already satisfied: mpmath>=0.19 in c:\users\akura\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from sympy->torch->groundingdino==0.1.0) (1.3.0)
# Requirement already satisfied: six>=1.5 in c:\users\akura\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from python-dateutil>=2.7->matplotlib>=2.1.0->pycocotools->groundingdino==0.1.0) (1.16.0)
# Building wheels for collected packages: groundingdino
#   Building wheel for groundingdino (setup.py): started
#   Building wheel for groundingdino (setup.py): finished with status 'done'
#   Created wheel for groundingdino: filename=groundingdino-0.1.0-py3-none-any.whl size=83836 sha256=aa501fbf0ef7177e40468ec5aa8606079422088faf66c962edd202e18db7984c
#   Stored in directory: C:\Users\akura\AppData\Local\Temp\pip-ephem-wheel-cache-6kh_mwjk\wheels\ac\88\b6\dcba77b622c1eb874c4720e94944b68de04ed72082abccaa75
# Successfully built groundingdino
# Installing collected packages: groundingdino
#   Attempting uninstall: groundingdino
#     Found existing installation: groundingdino 0.1.0
#     Uninstalling groundingdino-0.1.0:
#       Successfully uninstalled groundingdino-0.1.0
# Successfully installed groundingdino-0.1.0
# C:\Users\akura\individual_project_v1
# [notice] A new release of pip is available: 23.2.1 -> 23.3
# [notice] To update, run: C:\Users\akura\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip
# Requirement already satisfied: opencv-python in c:\users\akura\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (4.8.1.78)
# Requirement already satisfied: pycocotools in c:\users\akura\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (2.0.7)
# Requirement already satisfied: matplotlib in c:\users\akura\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (3.8.0)
# Requirement already satisfied: onnxruntime in c:\users\akura\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (1.16.1)
# Requirement already satisfied: onnx in c:\users\akura\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (1.14.1)
# Requirement already satisfied: ipykernel in c:\users\akura\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (6.19.4)
# Requirement already satisfied: numpy>=1.21.2 in c:\users\akura\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from opencv-python) (1.26.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\akura\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from matplotlib) (1.1.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\akura\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\akura\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from matplotlib) (4.43.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\akura\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in c:\users\akura\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from matplotlib) (22.0)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\akura\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from matplotlib) (10.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\akura\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from matplotlib) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\akura\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: coloredlogs in c:\users\akura\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from onnxruntime) (15.0.1)
# Requirement already satisfied: flatbuffers in c:\users\akura\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from onnxruntime) (23.5.26)
# Requirement already satisfied: protobuf in c:\users\akura\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from onnxruntime) (4.24.4)
# Requirement already satisfied: sympy in c:\users\akura\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from onnxruntime) (1.12)
# Requirement already satisfied: typing-extensions>=3.6.2.1 in c:\users\akura\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from onnx) (4.8.0)
# Requirement already satisfied: comm>=0.1.1 in c:\users\akura\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from ipykernel) (0.1.2)
# Requirement already satisfied: debugpy>=1.0 in c:\users\akura\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from ipykernel) (1.6.4)
# Requirement already satisfied: ipython>=7.23.1 in c:\users\akura\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from ipykernel) (8.7.0)
# Requirement already satisfied: jupyter-client>=6.1.12 in c:\users\akura\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from ipykernel) (7.4.8)
# Requirement already satisfied: matplotlib-inline>=0.1 in c:\users\akura\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from ipykernel) (0.1.6)
# Requirement already satisfied: nest-asyncio in c:\users\akura\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from ipykernel) (1.5.6)
# Requirement already satisfied: psutil in c:\users\akura\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from ipykernel) (5.9.4)
# Requirement already satisfied: pyzmq>=17 in c:\users\akura\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from ipykernel) (24.0.1)
# Requirement already satisfied: tornado>=6.1 in c:\users\akura\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from ipykernel) (6.2)
# Requirement already satisfied: traitlets>=5.4.0 in c:\users\akura\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from ipykernel) (5.8.0)
# Requirement already satisfied: backcall in c:\users\akura\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from ipython>=7.23.1->ipykernel) (0.2.0)
# Requirement already satisfied: decorator in c:\users\akura\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from ipython>=7.23.1->ipykernel) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\akura\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from ipython>=7.23.1->ipykernel) (0.18.2)
# Requirement already satisfied: pickleshare in c:\users\akura\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from ipython>=7.23.1->ipykernel) (0.7.5)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.11 in c:\users\akura\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from ipython>=7.23.1->ipykernel) (3.0.36)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\akura\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from ipython>=7.23.1->ipykernel) (2.13.0)
# Requirement already satisfied: stack-data in c:\users\akura\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from ipython>=7.23.1->ipykernel) (0.6.2)
# Requirement already satisfied: colorama in c:\users\akura\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from ipython>=7.23.1->ipykernel) (0.4.6)
# Requirement already satisfied: entrypoints in c:\users\akura\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from jupyter-client>=6.1.12->ipykernel) (0.4)
# Requirement already satisfied: jupyter-core>=4.9.2 in c:\users\akura\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from jupyter-client>=6.1.12->ipykernel) (5.1.1)
# Requirement already satisfied: six>=1.5 in c:\users\akura\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Requirement already satisfied: humanfriendly>=9.1 in c:\users\akura\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from coloredlogs->onnxruntime) (10.0)
# Requirement already satisfied: mpmath>=0.19 in c:\users\akura\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from sympy->onnxruntime) (1.3.0)
# Requirement already satisfied: pyreadline3 in c:\users\akura\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from humanfriendly>=9.1->coloredlogs->onnxruntime) (3.4.1)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in c:\users\akura\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel) (0.8.3)
# Requirement already satisfied: platformdirs>=2.5 in c:\users\akura\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from jupyter-core>=4.9.2->jupyter-client>=6.1.12->ipykernel) (3.11.0)
# Requirement already satisfied: pywin32>=1.0 in c:\users\akura\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from jupyter-core>=4.9.2->jupyter-client>=6.1.12->ipykernel) (305)
# Requirement already satisfied: wcwidth in c:\users\akura\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from prompt-toolkit<3.1.0,>=3.0.11->ipython>=7.23.1->ipykernel) (0.2.5)
# Requirement already satisfied: executing>=1.2.0 in c:\users\akura\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from stack-data->ipython>=7.23.1->ipykernel) (1.2.0)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\akura\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from stack-data->ipython>=7.23.1->ipykernel) (2.2.1)
# Requirement already satisfied: pure-eval in c:\users\akura\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from stack-data->ipython>=7.23.1->ipykernel) (0.2.2)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.2.1 -> 23.3
# [notice] To update, run: C:\Users\akura\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
# arguments.
#
# before you go, please download following 4 checkpoints:
# download RAM and Tag2Text checkpoints to ./pretrained/ from https://github.com/majinyu666/recognize-anything/tree/main#toolbox-checkpoints
# download GroundingDINO and SAM checkpoints to ./Grounded-Segment-Anything/ from step 1 of https://github.com/IDEA-Research/Grounded-Segment-Anything#running_man-grounded-sam-detect-and-segment-everything-with-text-prompt
config_file = "C:/Users/akura/individual_project_v1/Grounded-Segment-Anything/GroundingDINO/groundingdino/config/GroundingDINO_SwinT_OGC.py"
ram_checkpoint = "C:/Users/akura/individual_project_v1/pretrained/ram_swin_large_14m.pth"
tag2text_checkpoint = "C:/Users/akura/individual_project_v1/pretrained/tag2text_swin_14m.pth"
grounded_checkpoint = "C:/Users/akura/individual_project_v1/Grounded-Segment-Anything/groundingdino_swint_ogc.pth"
sam_checkpoint = "C:/Users/akura/individual_project_v1/Grounded-Segment-Anything/sam_vit_h_4b8939.pth"

box_threshold = 0.25
text_threshold = 0.2
iou_threshold = 0.5
import torch
device = "cuda" if torch.cuda.is_available() else "cpu"

# %%
# model loading, inference and visualization functions

import os
import random

import cv2
import groundingdino.datasets.transforms as T
import numpy as np
import torch
import torchvision
import torchvision.transforms as TS
from groundingdino.models import build_model
from groundingdino.util.slconfig import SLConfig
from groundingdino.util.utils import clean_state_dict, get_phrases_from_posmap
from PIL import Image, ImageDraw, ImageFont
from ram import inference_ram
from ram import inference_tag2text
from ram.models import ram
from ram.models import tag2text
from segment_anything import SamPredictor, build_sam


def load_model(model_config_path, model_checkpoint_path, device):
    args = SLConfig.fromfile(model_config_path)
    args.device = device
    model = build_model(args)
    checkpoint = torch.load(model_checkpoint_path, map_location="cpu")
    load_res = model.load_state_dict(
        clean_state_dict(checkpoint["model"]), strict=False)
    print(load_res)
    _ = model.eval()
    return model


def get_grounding_output(model, image, caption, box_threshold, text_threshold, device="cpu"):
    caption = caption.lower()
    caption = caption.strip()
    if not caption.endswith("."):
        caption = caption + "."
    model = model.to(device)
    image = image.to(device)
    with torch.no_grad():
        outputs = model(image[None], captions=[caption])
    logits = outputs["pred_logits"].cpu().sigmoid()[0]  # (nq, 256)
    boxes = outputs["pred_boxes"].cpu()[0]  # (nq, 4)
    logits.shape[0]

    # filter output
    logits_filt = logits.clone()
    boxes_filt = boxes.clone()
    filt_mask = logits_filt.max(dim=1)[0] > box_threshold
    logits_filt = logits_filt[filt_mask]  # num_filt, 256
    boxes_filt = boxes_filt[filt_mask]  # num_filt, 4
    logits_filt.shape[0]

    # get phrase
    tokenlizer = model.tokenizer
    tokenized = tokenlizer(caption)
    # build pred
    pred_phrases = []
    scores = []
    for logit, box in zip(logits_filt, boxes_filt):
        pred_phrase = get_phrases_from_posmap(
            logit > text_threshold, tokenized, tokenlizer)
        pred_phrases.append(pred_phrase + f"({str(logit.max().item())[:4]})")
        scores.append(logit.max().item())

    return boxes_filt, torch.Tensor(scores), pred_phrases


def draw_mask(mask, draw, random_color=False):
    if random_color:
        color = (random.randint(0, 255), random.randint(0, 255), random.randint(0, 255), 153)
    else:
        color = (30, 144, 255, 153)

    nonzero_coords = np.transpose(np.nonzero(mask))

    for coord in nonzero_coords:
        draw.point(coord[::-1], fill=color)


def draw_box(box, draw, label):
    # random color
    color = tuple(np.random.randint(0, 255, size=3).tolist())
    line_width = int(max(4, min(20, 0.006*max(draw.im.size))))
    draw.rectangle(((box[0], box[1]), (box[2], box[3])), outline=color,  width=line_width)

    if label:
        font_path = os.path.join(
            cv2.__path__[0], 'qt', 'fonts', 'DejaVuSans.ttf')
        font_path = r'C:\Windows\WinSxS\amd64_microsoft-windows-ui-biofeedback-library_31bf3856ad364e35_10.0.22621.1635_none_e1db5b96bb4fa9b1\NUIMDL2.ttf'
        font_size = int(max(12, min(60, 0.02*max(draw.im.size))))
        font = ImageFont.truetype(font_path, size=font_size)
        if hasattr(font, "getbbox"):
            bbox = draw.textbbox((box[0], box[1]), str(label), font)
        else:
            w, h = draw.textsize(str(label), font)
            bbox = (box[0], box[1], w + box[0], box[1] + h)
        draw.rectangle(bbox, fill=color)
        draw.text((box[0], box[1]), str(label), fill="white", font=font)

        draw.text((box[0], box[1]), label, font=font)
# from PIL import ImageFont

# def draw_box(box, draw, label):
#     # Random color
#     color = tuple(np.random.randint(0, 255, size=3).tolist())
#     line_width = int(max(4, min(20, 0.006 * max(draw.im.size))))
#     draw.rectangle(((box[0], box[1]), (box[2], box[3])), outline=color, width=line_width)

#     if label:
#         # Use a default font available in PIL
#         font = ImageFont.load_default()
#         w, h = draw.textsize(str(label), font)
#         bbox = (box[0], box[1], w + box[0], h + box[1])
#         draw.rectangle(bbox, fill=color)
#         draw.text((box[0], box[1]), str(label), fill="white", font=font)



@torch.no_grad()
def inference(
    raw_image, specified_tags, do_det_seg,
    tagging_model_type, tagging_model, grounding_dino_model, sam_model
):
    print(f"Start processing, image size {raw_image.size}")
    raw_image = raw_image.convert("RGB")

    # run tagging model
    normalize = TS.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
    transform = TS.Compose([
        TS.Resize((384, 384)),
        TS.ToTensor(),
        normalize
    ])

    image = raw_image.resize((384, 384))
    image = transform(image).unsqueeze(0).to(device)

    # Currently ", " is better for detecting single tags
    # while ". " is a little worse in some case
    if tagging_model_type == "RAM":
        res = inference_ram(image, tagging_model)
        tags = res[0].strip(' ').replace('  ', ' ').replace(' |', ',')
        tags_chinese = res[1].strip(' ').replace('  ', ' ').replace(' |', ',')
        print("Tags: ", tags)
        print("图像标签: ", tags_chinese)
    else:
        res = inference_tag2text(image, tagging_model, specified_tags)
        tags = res[0].strip(' ').replace('  ', ' ').replace(' |', ',')
        caption = res[2]
        print(f"Tags: {tags}")
        print(f"Caption: {caption}")

    # return
    if not do_det_seg:
        if tagging_model_type == "RAM":
            return tags.replace(", ", " | "), tags_chinese.replace(", ", " | "), None
        else:
            return tags.replace(", ", " | "), caption, None

    # run groundingDINO
    transform = T.Compose([
        T.RandomResize([800], max_size=1333),
        T.ToTensor(),
        T.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225]),
    ])

    image, _ = transform(raw_image, None)  # 3, h, w

    boxes_filt, scores, pred_phrases = get_grounding_output(
        grounding_dino_model, image, tags, box_threshold, text_threshold, device=device
    )
    print("GroundingDINO finished")

    # run SAM
    image = np.asarray(raw_image)
    sam_model.set_image(image)

    size = raw_image.size
    H, W = size[1], size[0]
    for i in range(boxes_filt.size(0)):
        boxes_filt[i] = boxes_filt[i] * torch.Tensor([W, H, W, H])
        boxes_filt[i][:2] -= boxes_filt[i][2:] / 2
        boxes_filt[i][2:] += boxes_filt[i][:2]

    boxes_filt = boxes_filt.cpu()
    # use NMS to handle overlapped boxes
    print(f"Before NMS: {boxes_filt.shape[0]} boxes")
    nms_idx = torchvision.ops.nms(boxes_filt, scores, iou_threshold).numpy().tolist()
    boxes_filt = boxes_filt[nms_idx]
    pred_phrases = [pred_phrases[idx] for idx in nms_idx]
    print(f"After NMS: {boxes_filt.shape[0]} boxes")

    transformed_boxes = sam_model.transform.apply_boxes_torch(boxes_filt, image.shape[:2]).to(device)

    masks, _, _ = sam_model.predict_torch(
        point_coords=None,
        point_labels=None,
        boxes=transformed_boxes.to(device),
        multimask_output=False,
    )
    print("SAM finished")

    # draw output image
    mask_image = Image.new('RGBA', size, color=(0, 0, 0, 0))

    mask_draw = ImageDraw.Draw(mask_image)
    for mask in masks:
        draw_mask(mask[0].cpu().numpy(), mask_draw, random_color=True)

    image_draw = ImageDraw.Draw(raw_image)

    for box, label in zip(boxes_filt, pred_phrases):
        draw_box(box, image_draw, label)

    out_image = raw_image.convert('RGBA')
    out_image.alpha_composite(mask_image)

    # return
    if tagging_model_type == "RAM":
        return tags.replace(", ", " | "), tags_chinese.replace(", ", " | "), out_image
    else:
        return tags.replace(", ", " | "), caption, out_image

# %%
# load 4 models

# load RAM
ram_model = ram(pretrained=ram_checkpoint, image_size=384, vit='swin_l')
ram_model.eval()
ram_model = ram_model.to(device)

# load Tag2Text
delete_tag_index = []  # filter out attributes and action categories which are difficult to grounding
for i in range(3012, 3429):
    delete_tag_index.append(i)

tag2text_model = tag2text(pretrained=tag2text_checkpoint,
                                    image_size=384,
                                    vit='swin_b',
                                    delete_tag_index=delete_tag_index)
tag2text_model.threshold = 0.64  # we reduce the threshold to obtain more tags
tag2text_model.eval()
tag2text_model = tag2text_model.to(device)

# load groundingDINO
grounding_dino_model = load_model(config_file, grounded_checkpoint, device=device)

# load SAM
sam_model = SamPredictor(build_sam(checkpoint=sam_checkpoint).to(device))
# Out:
# /encoder/layer/0/crossattention/self/query is tied
# /encoder/layer/0/crossattention/self/key is tied
# /encoder/layer/0/crossattention/self/value is tied
# /encoder/layer/0/crossattention/output/dense is tied
# /encoder/layer/0/crossattention/output/LayerNorm is tied
# /encoder/layer/0/intermediate/dense is tied
# /encoder/layer/0/output/dense is tied
# /encoder/layer/0/output/LayerNorm is tied
# /encoder/layer/1/crossattention/self/query is tied
# /encoder/layer/1/crossattention/self/key is tied
# /encoder/layer/1/crossattention/self/value is tied
# /encoder/layer/1/crossattention/output/dense is tied
# /encoder/layer/1/crossattention/output/LayerNorm is tied
# /encoder/layer/1/intermediate/dense is tied
# /encoder/layer/1/output/dense is tied
# /encoder/layer/1/output/LayerNorm is tied
# --------------
# C:/Users/akura/individual_project_v1/pretrained/ram_swin_large_14m.pth
# --------------
# load checkpoint from C:/Users/akura/individual_project_v1/pretrained/ram_swin_large_14m.pth
# vit: swin_l
# /encoder/layer/0/crossattention/self/query is tied
# /encoder/layer/0/crossattention/self/key is tied
# /encoder/layer/0/crossattention/self/value is tied
# /encoder/layer/0/crossattention/output/dense is tied
# /encoder/layer/0/crossattention/output/LayerNorm is tied
# /encoder/layer/0/intermediate/dense is tied
# /encoder/layer/0/output/dense is tied
# /encoder/layer/0/output/LayerNorm is tied
# /encoder/layer/1/crossattention/self/query is tied
# /encoder/layer/1/crossattention/self/key is tied
# /encoder/layer/1/crossattention/self/value is tied
# /encoder/layer/1/crossattention/output/dense is tied
# /encoder/layer/1/crossattention/output/LayerNorm is tied
# /encoder/layer/1/intermediate/dense is tied
# /encoder/layer/1/output/dense is tied
# /encoder/layer/1/output/LayerNorm is tied
# --------------
# C:/Users/akura/individual_project_v1/pretrained/tag2text_swin_14m.pth
# --------------
# load checkpoint from C:/Users/akura/individual_project_v1/pretrained/tag2text_swin_14m.pth
# vit: swin_b
# final text_encoder_type: bert-base-uncased
# Some weights of the model checkpoint at bert-base-uncased were not used when initializing BertModel: ['cls.predictions.transform.LayerNorm.bias', 'cls.seq_relationship.weight', 'cls.predictions.transform.dense.bias', 'cls.seq_relationship.bias', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.transform.dense.weight', 'cls.predictions.bias']
# - This IS expected if you are initializing BertModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# _IncompatibleKeys(missing_keys=[], unexpected_keys=['label_enc.weight'])

# %%
# let's try with an image

def inference_with_ram(img, do_det_seg):
    return inference(img, None, do_det_seg, "RAM", ram_model, grounding_dino_model, sam_model)

def inference_with_t2t(img, input_tags, do_det_seg):
    return inference(img, input_tags, do_det_seg, "Tag2Text", tag2text_model, grounding_dino_model, sam_model)

in_img = Image.open("C:/Users/akura/individual_project/demo/color_image_1.jpg")

print("-----\nRAM:")
ram_tags, ram_chinese_tags, ram_out_image = inference_with_ram(in_img, do_det_seg=True)
ram_out_image.thumbnail((500, 500))
display(ram_out_image)

print("-----\nTag2Text:")
t2t_tags, t2t_caption, t2t_out_image = inference_with_t2t(in_img, input_tags="", do_det_seg=True)
t2t_out_image.thumbnail((500, 500))
display(t2t_out_image)
# Out:
# -----
# RAM:
# Start processing, image size (1280, 720)
# Tags:  bottle, cloth, condiment, table, green, mat, mustard, pen, tablecloth, tomato sauce, tool, toothpaste, toy
# 图像标签:  瓶, 布, 调味品, 桌子/表格, 绿色, 地垫, 芥末, 笔/围栏, 桌布, 番茄酱, 工具, 牙膏, 玩具
# GroundingDINO finished
# Before NMS: 18 boxes
# After NMS: 10 boxes
# SAM finished
# <PIL.Image.Image image mode=RGBA size=500x281>
# -----
# Tag2Text:
# Start processing, image size (1280, 720)
# Tags: table, bottle
# Caption: a table topped with a green bulletin board covered in school supplies
# GroundingDINO finished
# Before NMS: 4 boxes
# After NMS: 4 boxes
# SAM finished
# <PIL.Image.Image image mode=RGBA size=500x281>
